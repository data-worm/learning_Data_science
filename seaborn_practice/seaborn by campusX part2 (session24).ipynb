# %% [markdown]
# # https://www.youtube.com/watch?v=kLWeKeqc9Ms&list=PLKnIA16_RmvbAlyx4_rdtR66B7EHX5k3z&index=80

# %%
import seaborn as sns
tips=sns.load_dataset('tips')
iris=sns.load_dataset('iris')

# %% [markdown]
# # Categorical data

# %%
# Categorical Plots
#     Categorical Scatter Plot
#     Stripplot
#     Swarmplot
# Categorical Distribution Plots
#     Boxplot
#     Violinplot
# Categorical Estimate Plot -> for central tendency
#     Barplot
#     Pointplot
#     Countplot

# Figure level function -> catplot

# %% [markdown]
# ### strip plot

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.stripplot(data=tips,x='day',y='total_bill')       #axis level function
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(sns.stripplot(data=tips,x='day',y='total_bill'),jitter=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(kind='strip',data=tips,x='day',y='total_bill',jitter=0.1,hue='sex')

# %%
sns.catplot(kind='swarm',data=tips,x='day',y='total_bill')       #swarm plot gives better distribution but works better with small datasets

# %% [markdown]
# ## categorical distribution plots

# %% [markdown]
# ### box plot

# %% [markdown]
# A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile [Q1], median, third quartile [Q3] and “maximum”). It can tell you about your outliers and what their values are. Boxplots can also tell you if your data is symmetrical, how tightly your data is grouped and if and how your data is skewed.

# %%
sns.boxplot(data=tips,x='sex',y='total_bill')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
#figure level

# %%
sns.catplot(kind='box',data=tips,x='sex',y='total_bill',hue='day')

# %%
#single box plot
sns.boxplot(data=tips,y='total_bill')
# Out:
# <Axes: ylabel='total_bill'>

# %% [markdown]
# ## violin plot : box+kde

# %%
sns.violinplot(data=tips,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(kind='violin',data=tips,x='day',y='total_bill',hue='sex',split=True)

# %% [markdown]
# ## Bar plot

# %%
sns.barplot(data=tips,x='sex',y='total_bill',hue='smoker')   #the wicks are the error bar
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ## point plot

# %%
sns.pointplot(data=tips,x='sex',y='total_bill',hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ## count plot

# %%
sns.countplot(data=tips,x='sex',hue='day')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ### facet using catplot

# %%
sns.catplot(data=tips,x='sex',y='total_bill',col='smoker',row='time')

# %% [markdown]
# # Reg plot or regression plot

# %% [markdown]
# ## 1.regplot
# ## 2.lmplot

# %%
sns.regplot(data=tips,x='total_bill',y='tip')     #95% confidence level
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data=tips,x='total_bill',y='tip',hue='sex')     #95% confidence level

# %%
#resid plot

# %%
sns.residplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Multi grid plot

# %% [markdown]
# ## Facet grid

# %%
g=sns.FacetGrid(data=tips,col='day',row='smoker') 
g.map(sns.violinplot,'sex','total_bill')
g.add_legend()
# Out:
# C:\Users\mrchi\anaconda3\Lib\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ## pairplot (imp)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# ## PairGrid (pairplot ka baap)

# %%
g1=sns.PairGrid(data=iris,hue='species')
g1.map(sns.scatterplot)

# %%
g2=sns.PairGrid(data=iris,hue='species')
g2.map_diag(sns.boxplot)
g2.map_offdiag(sns.scatterplot)

# %%
g3=sns.PairGrid(data=iris,hue='species')
g3.map_diag(sns.boxplot)
g3.map_offdiag(sns.kdeplot,fill=True)

# %%
g3=sns.PairGrid(data=iris,hue='species')
g3.map_diag(sns.histplot)
g3.map_upper(sns.kdeplot,fill=True)
g3.map_lower(sns.scatterplot)

# %%
g4=sns.PairGrid(data=iris,hue='species',vars=['sepal_width','petal_length'])
g4.map_diag(sns.histplot)
g4.map_upper(sns.kdeplot,fill=True)
g4.map_lower(sns.scatterplot)

# %% [markdown]
# ## Joint plot and joint grid

# %%
sns.jointplot(data=tips,x='total_bill',y='tip')

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',kind='kde',fill=True)

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',kind='hist',hue='sex')

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',kind='reg')

# %% [markdown]
# ### joint Grid

# %%
g6=sns.JointGrid(data=tips,x='total_bill',y='tip')
g6.plot(sns.scatterplot,sns.boxplot)

# %% [markdown]
# # utility functions

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
health=sns.load_dataset('healthexp')

# %%
sns.pairplot(health)
