# %% [markdown]
# # How to proceed:
# ## 1. check if its a linear data or not
# ## 2. remove columns that are not required
# ## 3. check corelation matrix
# ## 4. Do logistic regression and check for accuracy and confusion matrix

# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.metrics import precision_score,recall_score,f1_score

from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
df=pd.read_csv('framingham.csv')

# %%
df1=df.copy()

# %%
df1.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
# 5     0   43        2.0              0         0.0     0.0                0
# 6     0   63        1.0              0         0.0     0.0                0
# 7     0   45        2.0              1        20.0     0.0                0
# 8     1   52        1.0              0         0.0     0.0                0
# 9     1   43        1.0              1        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
df.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4238.000000  4238.000000  4133.000000    4238.000000  4209.000000
# mean      0.429212    49.584946     1.978950       0.494101     9.003089
# std       0.495022     8.572160     1.019791       0.500024    11.920094
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4185.000000      4238.000000   4238.000000  4238.000000  4188.000000
# mean      0.029630         0.005899      0.310524     0.025720   236.721585
# std       0.169584         0.076587      0.462763     0.158316    44.590334
# ...

# %%
df1.isnull().sum()*100/4238
# Out:
# male               0.000000
# age                0.000000
# education          2.477584
# currentSmoker      0.000000
# cigsPerDay         0.684285
# BPMeds             1.250590
# prevalentStroke    0.000000
# prevalentHyp       0.000000
# diabetes           0.000000
# totChol            1.179802
# sysBP              0.000000
# diaBP              0.000000
# BMI                0.448325
# heartRate          0.023596
# glucose            9.155262
# TenYearCHD         0.000000
# dtype: float64

# %%
df1
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %% [markdown]
# ## the plan is to fill the data with simple imputer. but also for the glucose column if it has a high covariance with output column we need to impute it or drop it

# %%
matrix = df1.corr()
print("Correlation matrix is : ")
coor_ds=pd.DataFrame(matrix)
coor_ds
# Out:
# Correlation matrix is :
#                      male       age  education  currentSmoker  cigsPerDay  \
# male             1.000000 -0.028979   0.017352       0.197596    0.317930
# age             -0.028979  1.000000  -0.165883      -0.213748   -0.192791
# education        0.017352 -0.165883   1.000000       0.018532    0.008085
# currentSmoker    0.197596 -0.213748   0.018532       1.000000    0.769690
# cigsPerDay       0.317930 -0.192791   0.008085       0.769690    1.000000
# BPMeds          -0.052506  0.122995  -0.010815      -0.048938   -0.046134
# prevalentStroke -0.004546  0.057655  -0.035112      -0.032988   -0.032707
# prevalentHyp     0.005313  0.307194  -0.081970      -0.103260   -0.066146
# diabetes         0.015708  0.101258  -0.038680      -0.044295   -0.037067
# totChol         -0.070322  0.262131  -0.023115      -0.046562   -0.026320
# sysBP           -0.035989  0.394302  -0.129631      -0.130230   -0.088780
# ...

# %%
dataplot = sns.heatmap(coor_ds, cmap="YlGnBu")
plt.show()

# %% [markdown]
# ## As we can see glucose does have a significant impact on the tenyearCHD, we cant drop the columns, rateher we use a simple imputer to impute the missing values.

# %%
imputer = SimpleImputer(missing_values = np.nan, 
                        strategy ='mean')
imputer.fit(df1)
transformed = imputer.transform(df1)
tranformed_df1=pd.DataFrame(transformed,columns=df1.columns)

# %%
tranformed_df1
# Out:
#       male   age  education  currentSmoker  cigsPerDay   BPMeds  \
# 0      1.0  39.0        4.0            0.0         0.0  0.00000
# 1      0.0  46.0        2.0            0.0         0.0  0.00000
# 2      1.0  48.0        1.0            1.0        20.0  0.00000
# 3      0.0  61.0        3.0            1.0        30.0  0.00000
# 4      0.0  46.0        3.0            1.0        23.0  0.00000
# ...    ...   ...        ...            ...         ...      ...
# 4233   1.0  50.0        1.0            1.0         1.0  0.00000
# 4234   1.0  51.0        3.0            1.0        43.0  0.00000
# 4235   0.0  48.0        2.0            1.0        20.0  0.02963
# 4236   0.0  44.0        1.0            1.0        15.0  0.00000
# 4237   0.0  52.0        2.0            0.0         0.0  0.00000
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                 0.0           0.0       0.0    195.0  106.0   70.0  26.97
# ...

# %%
tranformed_df1.isnull().sum()*100/4238
# Out:
# male               0.0
# age                0.0
# education          0.0
# currentSmoker      0.0
# cigsPerDay         0.0
# BPMeds             0.0
# prevalentStroke    0.0
# prevalentHyp       0.0
# diabetes           0.0
# totChol            0.0
# sysBP              0.0
# diaBP              0.0
# BMI                0.0
# heartRate          0.0
# glucose            0.0
# TenYearCHD         0.0
# dtype: float64

# %%
tranformed_df1
# Out:
#       male   age  education  currentSmoker  cigsPerDay   BPMeds  \
# 0      1.0  39.0        4.0            0.0         0.0  0.00000
# 1      0.0  46.0        2.0            0.0         0.0  0.00000
# 2      1.0  48.0        1.0            1.0        20.0  0.00000
# 3      0.0  61.0        3.0            1.0        30.0  0.00000
# 4      0.0  46.0        3.0            1.0        23.0  0.00000
# ...    ...   ...        ...            ...         ...      ...
# 4233   1.0  50.0        1.0            1.0         1.0  0.00000
# 4234   1.0  51.0        3.0            1.0        43.0  0.00000
# 4235   0.0  48.0        2.0            1.0        20.0  0.02963
# 4236   0.0  44.0        1.0            1.0        15.0  0.00000
# 4237   0.0  52.0        2.0            0.0         0.0  0.00000
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                 0.0           0.0       0.0    195.0  106.0   70.0  26.97
# ...

# %% [markdown]
# ## now lets plot the between cigsperday, sysbp and TenYearCHD

# %%
plt.scatter(tranformed_df1['cigsPerDay'], tranformed_df1['sysBP'], c =tranformed_df1['TenYearCHD'])
plt.show()

# %% [markdown]
# ### Lets apply linear logistic regression on the transformed data

# %%
X=tranformed_df1.iloc[:,0:-1]
y=tranformed_df1.iloc[:,-1:]

# %%
X
# Out:
#       male   age  education  currentSmoker  cigsPerDay   BPMeds  \
# 0      1.0  39.0        4.0            0.0         0.0  0.00000
# 1      0.0  46.0        2.0            0.0         0.0  0.00000
# 2      1.0  48.0        1.0            1.0        20.0  0.00000
# 3      0.0  61.0        3.0            1.0        30.0  0.00000
# 4      0.0  46.0        3.0            1.0        23.0  0.00000
# ...    ...   ...        ...            ...         ...      ...
# 4233   1.0  50.0        1.0            1.0         1.0  0.00000
# 4234   1.0  51.0        3.0            1.0        43.0  0.00000
# 4235   0.0  48.0        2.0            1.0        20.0  0.02963
# 4236   0.0  44.0        1.0            1.0        15.0  0.00000
# 4237   0.0  52.0        2.0            0.0         0.0  0.00000
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                 0.0           0.0       0.0    195.0  106.0   70.0  26.97
# ...

# %%
y
# Out:
#       TenYearCHD
# 0            0.0
# 1            0.0
# 2            0.0
# 3            1.0
# 4            0.0
# ...          ...
# 4233         1.0
# 4234         0.0
# 4235         0.0
# 4236         0.0
# 4237         0.0
#
# [4238 rows x 1 columns]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
clf1 = LogisticRegression()
clf1.fit(X_train,y_train)
y_pred1 = clf1.predict(X_test)

clf2=DecisionTreeClassifier()
clf2.fit(X_train,y_train)
y_pred2=clf2.predict(X_test)



print("Accuracy of Logistic Regression",accuracy_score(y_test,y_pred1))

print("Accuracy of Decision tree",accuracy_score(y_test,y_pred2))
print("Logistic Regression Confusion Matrix\n")
confusion_matrix(y_test,y_pred1)
# Out:
# Accuracy of Logistic Regression 0.8337264150943396
# Accuracy of Decision tree 0.7523584905660378
# Logistic Regression Confusion Matrix
# C:\Users\mrchi\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\mrchi\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([[702,   5],
#        [136,   5]], dtype=int64)

# %%
707/(707+141)
# Out:
# 0.8337264150943396

# %%
precision_score(y_test,y_pred1,average='weighted')
# Out:
# 0.7815567726392578

# %%
recall_score(y_test,y_pred1,average='weighted')
# Out:
# 0.8337264150943396

# %%
f1_score(y_test,y_pred1,average='weighted')
# Out:
# 0.7686502573670795

# %% [markdown]
# # lets do it using the poly
